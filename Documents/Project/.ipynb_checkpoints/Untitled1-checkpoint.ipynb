# %%
from symspellpy import SymSpell, Verbosity
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import faiss
import requests

# %%
df=pd.read_csv('all_players_stats.csv')
df.columns = df.columns.str.lower()
df['player'] = df['player'].str.replace('\xa0', ' ', regex=False).str.strip()
def spell_correct(word):
    suggestions = sym_spell.lookup(word, Verbosity.CLOSEST, max_edit_distance=2)
    return suggestions[0].term if suggestions else word
sym_spell = SymSpell(max_dictionary_edit_distance=2)
sym_spell.load_dictionary("frequency_dictionary_en_82_765.txt", term_index=0, count_index=1)  

df.columns = [' '.join([spell_correct(w) for w in col.split()]) for col in df.columns]
df.columns
# Out:
# C:\Users\PC-LENOVO\anaconda3\Lib\site-packages\symspellpy\symspellpy.py:1137: UserWarning: Failed to parse frequency count as a 64 bit integer.
#   warnings.warn("Failed to parse frequency count as a 64 bit integer.")
# Index(['team', 'jerseyno', 'player', 'position', 'apearances', 'substitutions',
#        'goals', 'penalties', 'yellowcards', 'redcards'],
#       dtype='object')

# %%
data=pd.read_csv('pandas_queries (1) (1).csv')
    
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
queries=[i for i in data['query']]
embeddings = model.encode(queries, convert_to_numpy=True)
embedding_dim = embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dim)
index.add(embeddings)
function_calls = [i for i in data['pandas_function_call']]
def retrieve_similar_queries(user_query, k=3):
    query_embedding = model.encode([user_query], convert_to_numpy=True)
    distances, indices = index.search(query_embedding, k)
    results = [(queries[i], function_calls[i]) for i in indices[0]]
    return results
def rag_pipeline(user_query):
    examples = retrieve_similar_queries(user_query)
    prompt = build_prompt(user_query, examples)
    result = query_grok_ai(prompt)
    return result    
def build_prompt(user_query, examples):
    prompt = """
You are an assistant that translates natural language into pandas code.
Use the examples to understand the pattern and write the correct function.
Return only the function in case of multiple function being availaible return onyl one of those.I ftwo sperate fu ctions are givn instead of , use space.
Examples:
"""
    for q, a in examples:
        prompt += f"Q: {q}\nA: {a}\n\n"
    prompt += f"Now answer this:\nQ: {user_query}\nA:"
    return prompt

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import faiss
df=pd.read_csv('all_players_stats.csv')
df.columns = df.columns.str.lower()
df['player'] = df['player'].str.replace('\xa0', ' ', regex=False).str.strip()
  
data=pd.read_csv('pandas_queries (1) (1).csv')    
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
queries=[i for i in data['query']]
embeddings = model.encode(queries, convert_to_numpy=True)
embedding_dim = embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dim)
index.add(embeddings)
function_calls = [i for i in data['pandas_function_call']]
def retrieve_similar_queries(user_query, k=3):
    query_embedding = model.encode([user_query], convert_to_numpy=True)
    distances, indices = index.search(query_embedding, k)
    results = [(queries[i], function_calls[i]) for i in indices[0]]
    return results
def rag_pipeline(user_query):
    examples = retrieve_similar_queries(user_query)
    prompt = build_prompt(user_query, examples)
    result = query_grok_ai(prompt)
    return result    
def build_prompt(user_query, examples):
    prompt = """
You are an assistant that translates natural language into pandas code.
Use the examples to understand the pattern and write the correct function.
Return only the function in case of multiple function being availaible return onyl one of those.I ftwo sperate fu ctions are givn instead of , use space.
Examples:
"""
    for q, a in examples:
        prompt += f"Q: {q}\nA: {a}\n\n"
    prompt += f"Now answer this:\nQ: {user_query}\nA:"
    return prompt

# %%
import os
from fastapi import FastAPI, UploadFile, Form
from fastapi.responses import JSONResponse
import pandas as pd
import io
import requests

app = FastAPI()

GROQ_API_KEY = os.getenv("API_KEY")
GROQ_URL = "https://api.groq.com/openai/v1/chat/completions"
MODEL = "meta-llama/llama-4-scout-17b-16e-instruct" 

chat_history = [
    {"role": "system", "content":'''I have been given a csv file i will give you prompt regarding that data and then you must just return the 
    function to be used nothing else assume that the column exists else that the function is possible 
    dont give code just the function to be used for example if asked that what is total money spent return df['money'].sum() .Do not give functions in or give
    only one of in case .Do not give alternative functions give only one in case it can be done in multiple ways if choice is given between a more than 1 step function
    and a 1 step function always prefer one step function pass/Do not give alternative functions give only one incase mpre than one options are availaible '''}
]
column_info = f"The DataFrame contains the following columns: {', '.join(df.columns)}"
chat_history[0]["content"] += "\n\n" + column_info
ferran=[]
def chat_with_groq(user_message,user_input):
    chat_history.append({"role": "user", "content": user_message})
    

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {GROQ_API_KEY}"
    }

    data = {
        "model": MODEL,
        "messages": chat_history
    }

    response = requests.post(GROQ_URL, headers=headers, json=data)
    response.raise_for_status()
    bot_message = response.json()["choices"][0]["message"]["content"]

    chat_history.append({"role": "assistant", "content": bot_message})
    ferran.append({"query":user_input,"pandas_function_call":bot_message})
    return bot_message





    
        
   
    
antony=[]

# %%
k=[]
import seaborn as sns
import matplotlib.pyplot as plt
while True:
    user_input = input("You: ")
    
    if user_input.lower() in ["exit", "quit"]:
        break
    examples = retrieve_similar_queries(user_input)
    prompt = build_prompt(user_input, examples)
    response = chat_with_groq(prompt,user_input)
    

    try:
        k.append(response)
        l = [line.strip() for line in response.split(";")]
       
        l=l[len(l)-1]
        print(l)
        
        if "df" in l:
            alu=eval(response, {"__builtins__": {}}, {"df": df})
            print(alu)
                
                
                     
            
        

    except KeyError as e:
        print(f"❌ KeyError: Column {str(e)} does not exist.")
        ferran.pop(len(ferran)-1)
     

    except TypeError as e:
        print(f"❌ TypeError: {str(e)}")
        ferran.pop(len(ferran)-1)
        
    except ValueError as e:
        print(f"❌ ValueError: {str(e)}")
        ferran.pop(len(ferran)-1)
       

    except AttributeError as e:
        print(f"❌ AttributeError: {str(e)}")
        ferran.pop(len(ferran)-1)
       

    except SyntaxError as e:
        print(f"❌ SyntaxError: {str(e)}   {response}")
        ferran.pop(len(ferran)-1)
        

    except NameError as e:
        print(f"❌ NameError: {str(e)}")
        ferran.pop(len(ferran)-1)
        

    except Exception as e:
        print(f"❌ Unexpected Error: {str(e)}")
        ferran.pop(len(ferran)-1)
# Out:
# You:  how many goals did Cristiano Ronaldo score
# df[df['player'] == 'Cristiano Ronaldo']['goals'].sum()
# 24
# You:  exit

# %%
ferran
# Out:
# [{'query': 'how many players do Manchester United have',
#   'pandas_function_call': "df[df['team'] == 'Manchester United']['player'].nunique()"},
#  {'query': 'Which team had highest no. of penalties',
#   'pandas_function_call': "df.groupby('team')['penalties'].sum().idxmax()"},
#  {'query': 'plot a chart between no .of teams and yellow cards',
#   'pandas_function_call': "df['yellowcards'].value_counts().plot(kind='bar')"},
#  {'query': 'plot chart between teams and yellow card',
#   'pandas_function_call': "df['team'].value_counts().plot(kind='bar')"},
#  {'query': 'plot a scatter plot between teams and yellow card',
#   'pandas_function_call': "df.groupby('team')['yellowcards'].sum().plot(kind='bar')"}]

# %%
fer=pd.DataFrame(ferran)

# %%
fer
# Out:
#                                                query  \
# 0         how many players do Manchester United have
# 1            Which team had highest no. of penalties
# 2  plot a chart between no .of teams and yellow c...
# 3           plot chart between teams and yellow card
# 4  plot a scatter plot between teams and yellow card
#
#                                 pandas_function_call
# 0  df[df['team'] == 'Manchester United']['player'...
# 1     df.groupby('team')['penalties'].sum().idxmax()
# 2  df['yellowcards'].value_counts().plot(kind='bar')
# 3         df['team'].value_counts().plot(kind='bar')
# 4  df.groupby('team')['yellowcards'].sum().plot(k...

# %%
import os 
filep='pandas_queries (1) (1).csv'
write_header = not os.path.exists(filep)

fer.to_csv(filep, mode='a', index=False, header=write_header)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.groupby('team')['yellowcards'].sum().plot.scatter(x=df.groupby('team').size())
#
# TypeError: PlotAccessor.scatter() missing 1 required positional argument: 'y'

# %%
df
# Out:
#                         team  jerseyno           player             position  \
# 0                    Arsenal         7      Bukayo Saka  Defender/Midfielder
# 1                    Arsenal         6          Gabriel             Defender
# 2                    Arsenal        32   Aaron Ramsdale           Goalkeeper
# 3                    Arsenal         4        Ben White             Defender
# 4                    Arsenal         8  Martin Odegaard           Midfielder
# ..                       ...       ...              ...                  ...
# 618  Wolverhampton Wanderers        21       John Ruddy           Goalkeeper
# 619  Wolverhampton Wanderers        27     Romain Saïss  Defender/Midfielder
# 620  Wolverhampton Wanderers        24       Tote Gomes             Defender
# 621  Wolverhampton Wanderers        37     Adama Traoré   Midfielder/Forward
# 622  Wolverhampton Wanderers        11          Trincão   Midfielder/Forward
#
#      apearances  substitutions  goals  penalties  yellowcards  redcards
# 0            40              3     12          2          6.0       0.0
# 1            37              1      5          0          7.0       1.0
# 2            37              0      0          0          1.0       0.0
# 3            37              0      0          0          3.0       0.0
# 4            36              4      7          0          4.0       0.0
# ..          ...            ...    ...        ...          ...       ...
# 618           5              1      0          0          0.0       0.0
# 619          32              0      3          0          6.0       0.0
# 620           5              0      0          0          1.0       0.0
# 621          11             12      1          0          0.0       0.0
# 622          16             14      3          0          0.0       0.0
#
# [623 rows x 10 columns]

# %%
l=df['player'].unique()

# %%
l
# Out:
# array(['Bukayo\xa0Saka', 'Gabriel', 'Aaron\xa0Ramsdale', 'Ben\xa0White',
#        'Martin\xa0Odegaard', 'Granit\xa0Xhaka', 'Gabriel\xa0Martinelli',
#        'Thomas\xa0Partey', 'Emile\xa0Smith Rowe', 'Kieran\xa0Tierney',
#        'Alexandre\xa0Lacazette', 'Cédric Soares', 'Takehiro\xa0Tomiyasu',
#        'Nuno Tavares', 'Albert\xa0Sambi Lokonga', 'Rob\xa0Holding',
#        'Pierre-Emerick\xa0Aubameyang', 'Eddie\xa0Nketiah',
#        'Mohamed\xa0El Neny', 'Bernd\xa0Leno', 'Nicolas\xa0Pépé',
#        'Ainsley\xa0Maitland-Niles', 'Calum\xa0Chambers',
#        'Sead\xa0Kolašinac', 'Pablo Marí', 'Folarin\xa0Balogun',
#        'Charlie\xa0Patino', 'Reiss\xa0Nelson', 'Cameron\xa0Archer',
#        'Leon\xa0Bailey', 'Emi\xa0Buendía', 'Matty\xa0Cash',
#        'Caleb\xa0Chukwuemeka', 'Carney\xa0Chukwuemeka',
#        'Philippe\xa0Coutinho', 'Keinan\xa0Davis', 'Lucas\xa0Digne',
#        'Douglas Luiz', 'Anwar\xa0El Ghazi', 'Frederic\xa0Guilbert',
#        'Kortney\xa0Hause', 'Conor\xa0Hourihane', 'Danny\xa0Ings',
#        'Tim\xa0Iroegbunam', 'Ezri\xa0Konsa', 'Hayden\xa0Lindley',
#        'Emiliano\xa0Martínez', 'John\xa0McGinn', 'Tyrone\xa0Mings',
#        'Marvelous\xa0Nakamba', 'Robin\xa0Olsen',
#        'Jaden\xa0Philogene-Bidace', 'Aaron\xa0Ramsey', 'Jacob\xa0Ramsey',
#        'Morgan\xa0Sanson', 'Jed\xa0Steer', 'Matt\xa0Targett',
#        'Bertrand\xa0Traoré', 'Trézéguet', 'Axel\xa0Tuanzebe',
#        'Ollie\xa0Watkins', 'Wesley', 'Ashley\xa0Young',
#        'Pontus\xa0Jansson', 'Christian\xa0Norgaard', 'Rico\xa0Henry',
#        'Bryan\xa0Mbeumo', 'Ethan\xa0Pinnock', 'Ivan\xa0Toney',
#        'Vitaly\xa0Janelt', 'Sergi\xa0Canós', 'Kristoffer\xa0Ajer',
#        'David\xa0Raya', 'Mathias\xa0Jensen', 'Alvaro Fernández',
#        'Mads\xa0Roerslev', 'Yoane\xa0Wissa', 'Mads\xa0Bech Sørensen',
#        'Frank\xa0Onyeka', 'Shandon\xa0Baptiste', 'Christian\xa0Eriksen',
#        'Saman\xa0Ghoddos', 'Mathias\xa0Jorgensen', 'Charlie\xa0Goode',
#        'Marcus\xa0Forss', 'Dominic\xa0Thompson', 'Mads\xa0Bidstrup',
#        'Jonas\xa0Lössl', 'Josh\xa0Dasilva', 'Tariqe\xa0Fosu-Henry',
#        'Halil Dervişoğlu', 'Fin\xa0Stevens', 'Myles\xa0Peart-Harris',
#        'Nathan\xa0Young-Coombes', 'Steven\xa0Alzate', 'Yves\xa0Bissouma',
#        'Dan\xa0Burn', 'Moisés\xa0Caicedo', 'Aaron\xa0Connolly',
#        'Marc\xa0Cucurella', 'Shane\xa0Duffy', 'Lewis\xa0Dunk',
#        'Evan\xa0Ferguson', 'Pascal\xa0Gross', 'Michał\xa0Karbownik',
#        'Adam\xa0Lallana', 'Tariq\xa0Lamptey', 'Marc\xa0Leonard',
#        'Jürgen\xa0Locadia', 'Alexis\xa0Mac Allister', 'Solly\xa0March',
#        'Neal\xa0Maupay', 'Jakub\xa0Moder', 'Andy\xa0Moran',
#        'Enock\xa0Mwepu', 'Odel\xa0Offiah', 'Taylor\xa0Richards',
#        'Haydon\xa0Roberts', 'Robert\xa0Sánchez', 'Jeremy\xa0Sarmiento',
#        'Kjell\xa0Scherpen', 'Jason\xa0Steele', 'Leandro\xa0Trossard',
#        'Antef\xa0Tsoungui', 'Ed\xa0Turns', 'Joël\xa0Veltman',
#        'Adam\xa0Webster', 'Danny\xa0Welbeck', 'Andi\xa0Zeqiri',
#        'Phil\xa0Bardsley', 'Ashley\xa0Barnes', 'Josh\xa0Brownhill',
#        'Nathan\xa0Collins', 'Jack\xa0Cork', 'Maxwel\xa0Cornet',
#        'Owen\xa0Dodgson', 'Jóhann Berg\xa0Gudmundsson',
#        'Wayne\xa0Hennessey', 'Aaron\xa0Lennon', 'Kevin\xa0Long',
#        'Matt\xa0Lowton', 'Dwight\xa0McNeil', 'Ben\xa0Mee',
#        'Erik\xa0Pieters', 'Nick\xa0Pope', 'Connor\xa0Roberts',
#        'Jay\xa0Rodriguez', 'Dale\xa0Stephens', 'James\xa0Tarkowski',
#        'Charlie\xa0Taylor', 'Matěj\xa0Vydra', 'Wout\xa0Weghorst',
#        'Ashley R\xa0Westwood', 'Chris\xa0Wood', 'César\xa0Azpilicueta',
#        'Lewis\xa0Baker', 'Ross\xa0Barkley', 'Marcus\xa0Bettinelli',
#        'Trevoh\xa0Chalobah', 'Ben\xa0Chilwell', 'Andreas\xa0Christensen',
#        'Emerson', 'Lewis\xa0Hall', 'Kai\xa0Havertz',
#        'Callum\xa0Hudson-Odoi', 'Reece\xa0James', 'Jorginho',
#        "N'Golo\xa0Kanté", 'Kenedy', 'Kepa Arrizabalaga',
#        'Mateo\xa0Kovačić', 'Ruben\xa0Loftus-Cheek', 'Romelu\xa0Lukaku',
#        'Marcos Alonso', 'Edouard\xa0Mendy', 'Mason\xa0Mount',
#        'Christian\xa0Pulišić', 'Antonio\xa0Rüdiger', 'Malang\xa0Sarr',
#        'Saúl Ñiguez', 'Xavier\xa0Simons', 'Jude\xa0Soonsup-Bell',
#        'Thiago Silva', 'Harvey\xa0Vale', 'Timo\xa0Werner',
#        'Hakim\xa0Ziyech', 'Kurt\xa0Zouma', 'Tayo\xa0Adaramola',
#        'Joachim\xa0Andersen', 'Jordan\xa0Ayew', 'Christian\xa0Benteke',
#        'Jack\xa0Butland', 'Nathaniel\xa0Clyne', 'Odsonne\xa0Edouard',
#        'Ebere\xa0Eze', 'Nathan\xa0Ferguson', 'Conor\xa0Gallagher',
#        'Vicente\xa0Guaita', 'Marc\xa0Guehi', 'Will\xa0Hughes',
#        'Martin\xa0Kelly', 'Cheikhou\xa0Kouyaté',
#        'Jean-Philippe\xa0Mateta', 'James\xa0McArthur',
#        'Luka\xa0Milivojević', 'Tyrick\xa0Mitchell', 'Michael\xa0Olise',
#        'Jesuran\xa0Rak-Sakyi', 'Jaïro\xa0Riedewald', 'Jeffrey\xa0Schlupp',
#        'James\xa0Tomkins', 'Joel\xa0Ward', 'Wilfried\xa0Zaha', 'Allan',
#        'Dele\xa0Alli', 'André Gomes', 'Asmir\xa0Begović',
#        'Jarrad\xa0Branthwaite', 'Dominic\xa0Calvert-Lewin', 'Cenk Tosun',
#        'Seamus\xa0Coleman', 'Tom\xa0Davies', 'Fabian\xa0Delph',
#        'Lewis\xa0Dobbin', 'Abdoulaye\xa0Doucouré',
#        'Jean-Philippe\xa0Gbamin', 'Ben\xa0Godfrey', 'Anthony\xa0Gordon',
#        'Demarai\xa0Gray', 'Mason\xa0Holgate', 'Alex\xa0Iwobi',
#        'Moise\xa0Kean', 'Michael\xa0Keane', 'Jonjoe\xa0Kenny',
#        'Yerry\xa0Mina', 'Vitaliy\xa0Mykolenko', 'Niels\xa0Nkounkou',
#        'Tyler\xa0Onyango', 'Nathan\xa0Patterson', 'Jordan\xa0Pickford',
#        'Isaac\xa0Price', 'Richarlison', 'Salomón\xa0Rondón',
#        'Ellis\xa0Simms', 'Andros\xa0Townsend', 'Donny\xa0van de Beek',
#        'Reece\xa0Welch', 'Luke\xa0Ayling', 'Patrick\xa0Bamford',
#        'Lewis\xa0Bate', 'Liam\xa0Cooper', 'Charlie\xa0Cresswell',
#        'Stuart\xa0Dallas', 'Cody\xa0Drameh', 'Adam\xa0Forshaw',
#        'Joe\xa0Gelhardt', 'Sam\xa0Greenwood', 'Jack\xa0Harrison',
#        'Hélder Costa', 'Leo\xa0Hjelde', 'Daniel\xa0James', 'Junior Firpo',
#        'Kristoffer\xa0Klaesson', 'Mateusz\xa0Klich', 'Robin\xa0Koch',
#        'Diego\xa0Llorente', 'Liam\xa0McCarron', 'Stuart\xa0McKinstry',
#        'Illan\xa0Meslier', 'Kalvin\xa0Phillips', 'Raphinha',
#        'Tyler\xa0Roberts', 'Rodrigo', 'Jamie\xa0Shackleton',
#        'Pascal\xa0Struijk', 'Crysencio\xa0Summerville',
#        'Marc\xa0Albrighton', 'Will\xa0Alves', 'Daniel\xa0Amartey',
#        'Harvey\xa0Barnes', 'Ryan\xa0Bertrand', 'Lewis\xa0Brunt',
#        'Cağlar Söyüncü', 'Timothy\xa0Castagne', 'Hamza\xa0Choudhury',
#        'Patson\xa0Daka', 'Vontae\xa0Daley-Campbell',
#        'Kiernan\xa0Dewsbury-Hall', 'Jonny\xa0Evans', 'Wesley\xa0Fofana',
#        'Kelechi\xa0Iheanacho', 'James\xa0Justin', 'Ademola\xa0Lookman',
#        'James\xa0Maddison', 'Wanya\xa0Marçal-Madivádua',
#        'Kasey\xa0McAteer', 'Nampalys\xa0Mendy', 'Wilfred\xa0Ndidi',
#        'Ayoze\xa0Pérez', 'Ricardo Pereira', 'Kasper\xa0Schmeichel',
#        'Boubakary\xa0Soumaré', 'Luke\xa0Thomas', 'Youri\xa0Tielemans',
#        'Jamie\xa0Vardy', 'Jannik\xa0Vestergaard', 'Danny\xa0Ward',
#        'Adrián', 'Trent\xa0Alexander-Arnold', 'Alisson Becker',
#        'Owen\xa0Beck', 'Harvey\xa0Blair', 'Conor\xa0Bradley',
#        'Luis\xa0Díaz', 'Diogo Jota', 'Ejijah\xa0Dixon-Bonner',
#        'Harvey\xa0Elliott', 'Fabinho', 'Roberto\xa0Firmino',
#        'Melkamu\xa0Frauendorf', 'Joe\xa0Gomez', 'Kaide\xa0Gordon',
#        'Jordan\xa0Henderson', 'Curtis\xa0Jones', 'Naby\xa0Keïta',
#        'Caoimhin\xa0Kelleher', 'Ibrahima\xa0Konaté', 'Billy\xa0Koumetio',
#        'Sadio\xa0Mané', 'Joël\xa0Matip', 'James\xa0Milner',
#        'Takumi\xa0Minamino', 'Tyler\xa0Morton', 'James\xa0Norris',
#        'Divock\xa0Origi', 'Alex\xa0Oxlade-Chamberlain', 'Nat\xa0Phillips',
#        'Andy\xa0Robertson', 'Mohamed\xa0Salah', 'Thiago Alcántara',
#        'Kostas\xa0Tsimikas', 'Virgil\xa0Van Dijk', 'Neco\xa0Williams',
#        'Max\xa0Woltman', 'Nathan\xa0Aké', 'Bernardo Silva',
#        'Finley\xa0Burns', 'Scott\xa0Carson', 'Kevin\xa0De Bruyne',
#        'Liam\xa0Delap', 'Ederson', 'Sam\xa0Edozie', 'CJ\xa0Egan-Riley',
#        'Fernandinho', 'Ferran Torres', 'Phil\xa0Foden', 'Gabriel Jesus',
#        'Jack\xa0Grealish', 'İlkay Gündogan', 'João Cancelo', 'Kayky',
#        'Ben\xa0Knight', 'Aymeric\xa0Laporte', 'Roméo\xa0Lavia',
#        'Riyad\xa0Mahrez', 'Luke\xa0Mbete-Tabu', 'James\xa0McAtee',
#        'Benjamin\xa0Mendy', 'Cole\xa0Palmer', 'Rodri', 'Rúben Dias',
#        'Zack\xa0Steffen', 'Raheem\xa0Sterling', 'John\xa0Stones',
#        'Kyle\xa0Walker', 'Josh\xa0Wilson-Esbrand',
#        'Olexsandr\xa0Zinchenko', 'Alex Telles', 'Eric\xa0Bailly',
#        'Bruno Fernandes', 'Edinson\xa0Cavani', 'David\xa0De Gea',
#        'Amad\xa0Diallo', 'Diogo Dalot', 'Anthony\xa0Elanga', 'Fred',
#        'Alejandro\xa0Garnacho', 'Mason\xa0Greenwood', 'Tom\xa0Heaton',
#        'Dean\xa0Henderson', 'Zidane\xa0Iqbal', 'Phil\xa0Jones',
#        'Juan Mata', 'Victor\xa0Lindelöf', 'Jesse\xa0Lingard',
#        'Harry\xa0Maguire', 'Anthony\xa0Martial', 'Nemanja\xa0Matić',
#        'Scott\xa0McTominay', 'Hannibal\xa0Mejbri', 'Tedan\xa0Mengi',
#        'Paul\xa0Pogba', 'Marcus\xa0Rashford', 'Cristiano\xa0Ronaldo',
#        'Jadon\xa0Sancho', 'Charlie\xa0Savage', 'Luke\xa0Shaw',
#        'Shola\xa0Shoretire', 'Raphaël\xa0Varane', 'Aaron\xa0Wan-Bissaka',
#        'Miguel\xa0Almirón', 'Bruno Guimarães', 'Ciaran\xa0Clark',
#        'Karl\xa0Darlow', 'Martin\xa0Dúbravka', 'Paul\xa0Dummett',
#        'Federico\xa0Fernández', 'Ryan\xa0Fraser', 'Dwight\xa0Gayle',
#        'Isaac\xa0Hayden', 'Jeff\xa0Hendrick', 'Joelinton',
#        'Emil\xa0Krafth', 'Jamaal\xa0Lascelles', 'Jamal\xa0Lewis',
#        'Sean\xa0Longstaff', 'Javi\xa0Manquillo', 'Jacob\xa0Murphy',
#        'Matt\xa0Ritchie', 'Allan\xa0Saint-Maximin', 'Fabian\xa0Schär',
#        'Jonjo\xa0Shelvey', 'Kieran\xa0Trippier', 'Joe\xa0Willock',
#        'Callum\xa0Wilson', 'Freddie\xa0Woodman', 'Max\xa0Aarons',
#        'Sam\xa0Byram', 'Todd\xa0Cantwell', 'Kieran\xa0Dowell',
#        'Dimitris\xa0Giannoulis', 'Ben\xa0Gibson', 'Billy\xa0Gilmour',
#        'Angus\xa0Gunn', 'Grant\xa0Hanley', 'Adam\xa0Idah', 'Tim\xa0Krul',
#        'Pierre\xa0Lees-Melou', 'Michael\xa0McGovern', 'Kenny\xa0McLean',
#        'Bali\xa0Mumba', 'Mathias\xa0Normann', 'Andrew\xa0Omobamidele',
#        'Ozan Kabak', 'Przemysław\xa0Placheta', 'Teemu\xa0Pukki',
#        'Milot\xa0Rashica', 'Jonathan\xa0Rowe', 'Lukas\xa0Rupp',
#        'Josh\xa0Sargent', 'Jacob\xa0Sörensen', 'Tony\xa0Springett',
#        'Christos\xa0Tzolis', 'Brandon\xa0Williams',
#        'Christoph\xa0Zimmermann', 'Che\xa0Adams', 'Adam\xa0Armstrong',
#        'Stuart\xa0Armstrong', 'Jan\xa0Bednarek', 'Armando\xa0Broja',
#        'Willy\xa0Caballero', 'Ibrahima\xa0Diallo', 'Moussa\xa0Djenepo',
#        'Mohamed\xa0Elyounoussi', 'Fraser\xa0Forster',
#        'Tino\xa0Livramento', 'Shane\xa0Long', 'Lyanco',
#        'Alex\xa0McCarthy', 'Michael\xa0Obafemi', 'Romain\xa0Perraud',
#        'Nathan\xa0Redmond', 'Oriol\xa0Romeu', 'Mohammed\xa0Salisu',
#        'Thierry\xa0Small', 'Will\xa0Smallbone', 'Jack\xa0Stephens',
#        'Nathan\xa0Tella', 'Yann\xa0Valery', 'Theo\xa0Walcott',
#        'Kyle\xa0Walker-Peters', 'James\xa0Ward-Prowse',
#        'Rodrigo\xa0Bentancur', 'Steven\xa0Bergwijn', 'Bryan Gil',
#        'Cameron\xa0Carter-Vickers', 'Jack\xa0Clarke', 'Ben\xa0Davies',
#        'Eric\xa0Dier', 'Matt\xa0Doherty', 'Emerson Royal',
#        'Pierluigi\xa0Gollini', 'SON\xa0Heung-min',
#        'Pierre-Emile\xa0Hojbjerg', 'Nile\xa0John', 'Harry\xa0Kane',
#        'Dejan\xa0Kulusekvski', 'Hugo\xa0Lloris',
#        "J'Neil\xa0Lloyd-Bennett", 'Giovani\xa0Lo Celso', 'Lucas Moura',
#        'Tanguy\xa0Ndombèlé', 'Maksim\xa0Paskotši', 'Joe\xa0Rodon',
#        'Cristian\xa0Romero', 'Davinson\xa0Sánchez', 'Dane\xa0Scarlett',
#        'Sergio Reguilón', 'Ryan\xa0Sessegnon', 'Oliver\xa0Skipp',
#        'Japhet\xa0Tanganga', 'Harry\xa0Winks', 'Dan\xa0Bachmann',
#        'Craig\xa0Cathcart', 'Tom\xa0Cleverley', 'Kamil\xa0Conteh',
#        'Troy\xa0Deeney', 'Emmanuel\xa0Dennis', 'Rob\xa0Elliot',
#        'Peter\xa0Etebo', 'Kiko\xa0Femenía', 'Ashley\xa0Fletcher',
#        'Shaqai\xa0Forde', 'Ben\xa0Foster', 'Dan\xa0Gosling',
#        'Cucho\xa0Hernández', 'João Pedro', 'Christian\xa0Kabasele',
#        'Samuel\xa0Kalu', 'Hassane\xa0Kamara', 'Edo\xa0Kayembe',
#        'Josh\xa0King', 'Juraj\xa0Kucka', 'Imran\xa0Louza',
#        'Adam\xa0Masina', 'James\xa0Morris', 'Jeremy\xa0Ngakia',
#        'Nicolas\xa0Nkoulou', 'Ozan Tufan', 'Danny\xa0Rose', 'Samir',
#        'Ismaïla\xa0Sarr', 'Ken\xa0Sema', 'Francisco\xa0Sierralta',
#        'Moussa\xa0Sissoko', 'William\xa0Troost-Ekong', 'Aji\xa0Alese',
#        'Michail\xa0Antonio', 'Keenan\xa0Appiah-Forson',
#        'Alphonse\xa0Aréola', 'Harrison\xa0Ashby', 'Jamal\xa0Baptiste',
#        'Saïd\xa0Benrahma', 'Jarrod\xa0Bowen', 'Daniel\xa0Chesters',
#        'Vladimír\xa0Coufal', 'Aaron\xa0Cresswell', 'Craig\xa0Dawson',
#        'Issa\xa0Diop', 'Łukasz\xa0Fabiański', 'Pablo\xa0Fornals',
#        'Ryan\xa0Fredericks', 'Ben\xa0Johnson', 'Alex\xa0Král',
#        'Manuel\xa0Lanzini', 'Emmanuel\xa0Longelo', 'Arthur\xa0Masuaku',
#        'Mark\xa0Noble', 'Angelo\xa0Ogbonna', 'Sonny\xa0Perkins',
#        'Freddie\xa0Potts', 'Declan\xa0Rice', 'Tomáš\xa0Souček',
#        'Nikola\xa0Vlašić', 'Andriy\xa0Yarmolenko', 'Rayan\xa0Aït-Nouri',
#        'Willy\xa0Boly', 'Bruno Jordão', 'Chem\xa0Campbell', 'Chiquinho',
#        'Conor\xa0Coady', 'Luke\xa0Cundle', 'Daniel Podence',
#        'Leander\xa0Dendoncker', 'Fábio Silva', 'Morgan\xa0Gibbs-White',
#        'HWANG\xa0Hee-chan', 'Ki-Jana\xa0Hoever', 'Raúl\xa0Jiménez',
#        'João Moutinho', 'Jonny', 'José Sá', 'Max\xa0Kilman', 'Marçal',
#        'Yerson\xa0Mosquera', 'Nélson Semedo', 'Pedro Neto', 'Rúben Neves',
#        'John\xa0Ruddy', 'Romain\xa0Saïss', 'Tote Gomes',
#        'Adama\xa0Traoré', 'Trincão'], dtype=object)
