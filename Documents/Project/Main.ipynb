# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import faiss
import time

# %%
df=pd.read_csv('health_activity_data.csv')
df.columns = df.columns.str.lower()

# %%
data=pd.read_csv('pandas_queries (1) (1).csv')
    
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
queries=[i for i in data['query']]
embeddings = model.encode(queries, convert_to_numpy=True)
embedding_dim = embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dim)
index.add(embeddings)
function_calls = [i for i in data['pandas_function_call']]
def retrieve_similar_queries(user_query, k=3):
    query_embedding = model.encode([user_query], convert_to_numpy=True)
    distances, indices = index.search(query_embedding, k)
    results = [(queries[i], function_calls[i]) for i in indices[0]]
    return results
def rag_pipeline(user_query):
    examples = retrieve_similar_queries(user_query)
    prompt = build_prompt(user_query, examples)
    result = query_grok_ai(prompt)
    return result    
def build_prompt(user_query, examples):
    prompt = """
You are an assistant that translates natural language into pandas code.
Use the examples to understand the pattern and write the correct function.
Return only the function in case of multiple function being availaible return onyl one of those.If two sperate functions are given instead of , use space.
Examples:
"""
    for q, a in examples:
        prompt += f"Q: {q}\nA: {a}\n\n"
    prompt += f"Now answer this:\nQ: {user_query}\nA:"
    return prompt

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import faiss


  
data=pd.read_csv('pandas_queries (1) (1).csv')    
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
queries=[i for i in data['query']]
embeddings = model.encode(queries, convert_to_numpy=True)
embedding_dim = embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dim)
index.add(embeddings)
function_calls = [i for i in data['pandas_function_call']]
def retrieve_similar_queries(user_query, k=3):
    query_embedding = model.encode([user_query], convert_to_numpy=True)
    distances, indices = index.search(query_embedding, k)
    results = [(queries[i], function_calls[i]) for i in indices[0]]
    return results
def rag_pipeline(user_query):
    examples = retrieve_similar_queries(user_query)
    prompt = build_prompt(user_query, examples)
    result = query_grok_ai(prompt)
    return result    
def build_prompt(user_query, examples):
    prompt = """
You are an assistant that translates natural language into pandas code.
Use the examples to understand the pattern and write the correct function.
Return only the function in case of multiple function being availaible return onyl one of those.I ftwo sperate fu ctions are givn instead of , use space.
Examples:
"""
    for q, a in examples:
        prompt += f"Q: {q}\nA: {a}\n\n"
    prompt += f"Now answer this:\nQ: {user_query}\nA:"
    return prompt

# %%
import os
from fastapi import FastAPI, UploadFile, Form
from fastapi.responses import JSONResponse
import pandas as pd
import io
import requests

app = FastAPI()

GROQ_API_KEY = os.getenv("API_KEY")
GROQ_URL = "https://api.groq.com/openai/v1/chat/completions"
MODEL = "meta-llama/llama-4-scout-17b-16e-instruct" 

chat_history = [
    {"role": "system", "content":'''I have been given a csv file i will give you prompt regarding that data and then you must just return the 
    function to be used nothing else assume that the column exists else that the function is possible 
    dont give code just the function to be used for example if asked that what is total money spent return df['money'].sum() .Do not give functions in or give
    only one of in case .Do not give alternative functions give only one in case it can be done in multiple ways if choice is given between a more than 1 step function
    and a 1 step function always prefer one step function pass/Do not give alternative functions give only one incase mpre than one options are availaible.while using columnname match from one of columns present  '''}
]
column_info = f"The DataFrame contains the following columns: {', '.join(df.columns)}"
chat_history[0]["content"] += "\n\n" + column_info
first_five_rows = df.head(5)
data_summary = first_five_rows.to_json(orient='records')
chat_history.append({"role":"system","content":f"Here are the first five rows of my data: {data_summary}."})
datap=[]
def chat_with_groq(user_message,user_input):
    chat_history.append({"role": "user", "content": user_message})
    

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {GROQ_API_KEY}"
    }

    data = {
        "model": MODEL,
        "messages": chat_history
    }

    response = requests.post(GROQ_URL, headers=headers, json=data)
    response.raise_for_status()
    bot_message = response.json()["choices"][0]["message"]["content"]

    chat_history.append({"role": "assistant", "content": bot_message})
    datap.append({"query":user_input,"pandas_function_call":bot_message})
    return bot_message

# %%
import seaborn as sns
import matplotlib.pyplot as plt
while True:
    user_input = input("You: ")
    
    if user_input.lower() in ["exit", "quit"]:
        break
    examples = retrieve_similar_queries(user_input)
    prompt = build_prompt(user_input, examples)
    response = chat_with_groq(prompt,user_input)
    

    try:
        
        l = [line.strip() for line in response.split(";")]
       
        l=l[len(l)-1]
       
        print(l)
        
        
        
        if "df" in l:
            alu=eval(response, {"__builtins__": {}}, {"df": df})
            print(alu)
                
                
                     
            
        

    except KeyError as e:
        print(f"❌ KeyError: Column {str(e)} does not exist.")
        datap.pop(len(datap)-1)
     

    except TypeError as e:
        print(f"❌ TypeError: {str(e)}")
        datap.pop(len(datap)-1)
        
    except ValueError as e:
        print(f"❌ ValueError: {str(e)}")
        datap.pop(len(datap)-1)
       

    except AttributeError as e:
        print(f"❌ AttributeError: {str(e)}")
        datap.pop(len(datap)-1)
       

    except SyntaxError as e:
        print(f"❌ SyntaxError: {str(e)}   {response}")
        datap.pop(len(datap)-1)
        

    except NameError as e:
        print(f"❌ NameError: {str(e)}")
        datap.pop(len(datap)-1)
        

    except Exception as e:
        print(f"❌ Unexpected Error: {str(e)}")
        datap.pop(len(datap)-1)
    time.sleep(1)
# Out:
# You:  calculate correlation of height and weight
# df[['height_cm', 'weight_kg']].corr().iloc[0,1]
# -0.05037718176212504
# You:   calculate correlation of height and weight in women
# df[df['gender'] == 'Female'][['height_cm', 'weight_kg']].corr().iloc[0,1]
# -0.09145422851594309
# You:  calculate correlation of height and weight in men
# df[df['gender'] == 'Male'][['height_cm', 'weight_kg']].corr().iloc[0,1]
# -0.01441903599585993
# You:  calculate correlation of diabetice people and wieght
# df[df['diabetic'] == 'Yes'][['weight_kg']].std()
# weight_kg    19.271587
# dtype: float64
# You:  exit

# %%
datap
# Out:
# [{'query': 'how man people with age greater than 40 suffer from diabities',
#   'pandas_function_call': "(df['age'] > 40) & (df['diabetic'] == 'Yes')"},
#  {'query': 'no. people with age greater than 40 and suffer from diabities',
#   'pandas_function_call': "((df['age'] >40) & (df['diabetic'] == 'Yes')).sum()"},
#  {'query': 'no.of people with age greater than 60 and suffer from diabities',
#   'pandas_function_call': "((df['age'] >60) & (df['diabetic'] == 'Yes')).sum()"},
#  {'query': 'no.of people with weight greater than 80 and suffer from hear disorder',
#   'pandas_function_call': "((df['weight_kg'] >80) & (df['heart_disease'] == 'Yes')).sum()"},
#  {'query': 'women with age greater than 60 and have heart disease',
#   'pandas_function_call': "((df['age'] >60) & (df['gender'] == 'Female') & (df['heart_disease'] == 'Yes')).sum()"},
#  {'query': 'no.of people who walk more than 10000 steps and have hear disease',
#   'pandas_function_call': "((df['daily_steps'] >10000) & (df['heart_disease'] == 'Yes')).sum()"},
#  {'query': 'no. of people who have diabities and hear disease',
#   'pandas_function_call': "((df['diabetic'] == 'Yes') & (df['heart_disease'] == 'Yes')).sum()"},
#  {'query': 'no.of people who are diabetic but do not have heart disease',
#   'pandas_function_call': "((df['diabetic'] == 'Yes') & (df['heart_disease'] == 'No')).sum()"},
#  {'query': 'no.of people who are not diabetic but do  have heart disease',
#   'pandas_function_call': "((df['diabetic'] == 'No') & (df['heart_disease'] == 'Yes')).sum()"},
#  {'query': 'calculate correlation of height and weight',
#   'pandas_function_call': "df[['height_cm', 'weight_kg']].corr().iloc[0,1]"},
#  {'query': ' calculate correlation of height and weight in women',
#   'pandas_function_call': "df[df['gender'] == 'Female'][['height_cm', 'weight_kg']].corr().iloc[0,1]"},
#  {'query': 'calculate correlation of height and weight in men',
#   'pandas_function_call': "df[df['gender'] == 'Male'][['height_cm', 'weight_kg']].corr().iloc[0,1]"},
#  {'query': 'calculate correlation of diabetice people and wieght',
#   'pandas_function_call': "df[df['diabetic'] == 'Yes'][['weight_kg']].std()"}]

# %%
fer=pd.DataFrame(datap)

# %%
fer
# Out:
#                                                 query  \
# 0   how man people with age greater than 40 suffer...
# 1   no. people with age greater than 40 and suffer...
# 2   no.of people with age greater than 60 and suff...
# 3   no.of people with weight greater than 80 and s...
# 4   women with age greater than 60 and have heart ...
# 5   no.of people who walk more than 10000 steps an...
# 6   no. of people who have diabities and hear disease
# 7   no.of people who are diabetic but do not have ...
# 8   no.of people who are not diabetic but do  have...
# 9          calculate correlation of height and weight
# 10   calculate correlation of height and weight in...
# 11  calculate correlation of height and weight in men
# 12  calculate correlation of diabetice people and ...
#
#                                  pandas_function_call
# 0        (df['age'] > 40) & (df['diabetic'] == 'Yes')
# 1   ((df['age'] >40) & (df['diabetic'] == 'Yes'))....
# 2   ((df['age'] >60) & (df['diabetic'] == 'Yes'))....
# 3   ((df['weight_kg'] >80) & (df['heart_disease'] ...
# 4   ((df['age'] >60) & (df['gender'] == 'Female') ...
# 5   ((df['daily_steps'] >10000) & (df['heart_disea...
# 6   ((df['diabetic'] == 'Yes') & (df['heart_diseas...
# 7   ((df['diabetic'] == 'Yes') & (df['heart_diseas...
# 8   ((df['diabetic'] == 'No') & (df['heart_disease...
# 9     df[['height_cm', 'weight_kg']].corr().iloc[0,1]
# 10  df[df['gender'] == 'Female'][['height_cm', 'we...
# 11  df[df['gender'] == 'Male'][['height_cm', 'weig...
# 12   df[df['diabetic'] == 'Yes'][['weight_kg']].std()

# %%
import os 
filep='pandas_queries (1) (1).csv'
write_header = not os.path.exists(filep)

fer.to_csv(filep, mode='a', index=False, header=write_header)
data=pd.read_csv('pandas_queries (1) (1).csv')
final=data.drop_duplicates()
final.to_csv(filep,index=False,header=write_header)

# %%
data=pd.read_csv('pandas_queries (1) (1).csv')

# %%
data
# Out:
#                               Calculate sum for profit  \
# 0                          Show relationship of height
# 1                             Describe values of score
# 2                       Compute median for temperature
# 3                        Compute percentile for weight
# 4                              Count entries in profit
# ..                                                 ...
# 799  no.of people who are not diabetic but do  have...
# 800         calculate correlation of height and weight
# 801   calculate correlation of height and weight in...
# 802  calculate correlation of height and weight in men
# 803  calculate correlation of diabetice people and ...
#
#                                     df['profit'].sum()
# 0                                  df.corr()['height']
# 1                               df['score'].describe()
# 2                           df['temperature'].median()
# 3                           df['weight'].quantile(0.5)
# 4                                 df['profit'].count()
# ..                                                 ...
# 799  ((df['diabetic'] == 'No') & (df['heart_disease...
# 800    df[['height_cm', 'weight_kg']].corr().iloc[0,1]
# 801  df[df['gender'] == 'Female'][['height_cm', 'we...
# 802  df[df['gender'] == 'Male'][['height_cm', 'weig...
# 803   df[df['diabetic'] == 'Yes'][['weight_kg']].std()
#
# [804 rows x 2 columns]
